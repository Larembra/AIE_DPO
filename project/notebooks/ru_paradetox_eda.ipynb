# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
splits = {'train': 'train.tsv', 'validation': 'dev.tsv'}
df_train = pd.read_csv("hf://datasets/s-nlp/ru_paradetox/" + splits["train"], sep="\t")
df_val = pd.read_csv("hf://datasets/s-nlp/ru_paradetox/" + splits["validation"], sep="\t")

# %%
df_train.head()
# Out:
#                                     ru_toxic_comment  \
# 0  и,чё,блядь где этот херой был до этого со свои...
# 1  и,чё,блядь где этот херой был до этого со свои...
# 2  и,чё,блядь где этот херой был до этого со свои...
# 3                     О, а есть деанон этого петуха?
# 4   херну всякую пишут,из-за этого лайка.долбоебизм.
#
#                                   ru_neutral_comment
# 0  Ну и где этот герой был,со своими доказательст...
# 1  Где этот герой был до этого со своими доказате...
# 2  и,где этот герой был до этого со своими доказа...
# 3                                   О, а есть деанон
# 4             Чушь всякую пишут, из- за этого лайка.

# %%
df_val.head()
# Out:
#                                     ru_toxic_comment  \
# 0  пиздеж! температуры горения хватит чтобы её ра...
# 1  пиздеж! температуры горения хватит чтобы её ра...
# 2  пиздеж! температуры горения хватит чтобы её ра...
# 3           а ты чмо там был.ты вообще служил.гандон
# 4                пиздабол ---- а сам где кормишься ?
#
#                                   ru_neutral_comment
# 0  Враньё! Температуры горения хватит чтобы ее ра...
# 1  неправда,температуры горения хватит чтобы расп...
# 2  Враньё! Температуры горения хватит на чтобы её...
# 3                    А ты там был? Ты вообще служил?
# 4                              а сам где кормишься ?

# %%
df_train.describe()
# Out:
#                                          ru_toxic_comment  \
# count                                               11090
# unique                                               6948
# top     и,чё,блядь где этот херой был до этого со свои...
# freq                                                    3
#
#             ru_neutral_comment
# count                    11090
# unique                   10873
# top     Я там через день бываю
# freq                         3

# %%
df_val.describe()
# Out:
#                                          ru_toxic_comment  \
# count                                                1116
# unique                                                800
# top     пиздеж! температуры горения хватит чтобы её ра...
# freq                                                    3
#
#                           ru_neutral_comment
# count                                   1116
# unique                                  1087
# top     как его вообще со стадиона выпустили
# freq                                       2

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11090 entries, 0 to 11089
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ru_toxic_comment    11090 non-null  object
#  1   ru_neutral_comment  11090 non-null  object
# dtypes: object(2)
# memory usage: 173.4+ KB

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1116 entries, 0 to 1115
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ru_toxic_comment    1116 non-null   object
#  1   ru_neutral_comment  1116 non-null   object
# dtypes: object(2)
# memory usage: 17.6+ KB
